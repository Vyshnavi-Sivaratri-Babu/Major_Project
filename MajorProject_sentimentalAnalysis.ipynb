# %% [markdown]
# <a href="https://colab.research.google.com/github/Vyshnavi-Sivaratri-Babu/Major_Project/blob/main/MajorProject_sentimentalAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 5.5MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs=SentimentIntensityAnalyzer

# %%
# web Scraping
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
urls = ['https://inshorts.com/en/read/national',
        'https://inshorts.com/en/read/sports',
        'https://inshorts.com/en/read/technology']

def build_dataset(urls):
  news_data=[]
  for url in urls:
    news_category = url.split('/')[-1]
    data = requests.get(url)
    soup = BeautifulSoup(data.content)
    
    news_articles =[{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                     'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                     'news_category':news_category}
                     
                     for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                                 soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]
    news_data.extend(news_articles)

  df = pd.DataFrame(news_data)
  df = df[['news_headline','news_article','news_category']]
  return df

# %%
df = build_dataset(urls)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  BMC issues 'work from home' order for teachers...  ...      national
# 1  Former Union Minister Dilip Gandhi, who tested...  ...      national
# 2  Cong announces 14 names for Puducherry polls, ...  ...      national
# 3  Himachal Pradesh MP Ram Swaroop Sharma found d...  ...      national
# 4  NIA seizes Mercedes used by Sachin Vaze with n...  ...      national
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
df=pd.read_csv('/content/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   BMC issues 'work from home' order for teachers...  ...      national
# 1   Former Union Minister Dilip Gandhi, who tested...  ...      national
# 2   Cong announces 14 names for Puducherry polls, ...  ...      national
# 3   Himachal Pradesh MP Ram Swaroop Sharma found d...  ...      national
# 4   NIA seizes Mercedes used by Sachin Vaze with n...  ...      national
# 5   India reports highest daily COVID-19 cases in ...  ...      national
# 6   DU teachers march to CM residence to protest o...  ...      national
# 7   Total lockdown in Pune not necessary right now...  ...      national
# 8   Delhi govt sets up its own education board, ge...  ...      national
# 9   Why no women SHOs in Delhi: Delhi Commission f...  ...      national
# 10  Bhojpuri actor, 1 other held in Delhi with fak...  ...      national
# 11  Hero for Indians too: PM on Sheikh Mujibur Rah...  ...      national
# 12  Action against schools for reopening Classes 1...  ...      national
# 13  Beneficiaries in Pune to get Covaxin due to Co...  ...      national
# 14  Mother of slain Walayar girls to contest again...  ...      national
# 15  Congress is not Nazi Party, RSS: Rahul Gandhi ...  ...      national
# 16  Class 11 student, others kidnap classmate in P...  ...      national
# 17  Govt to shut down handicrafts export corp, off...  ...      national
# 18  Health policy premium cannot be 'arbitrarily' ...  ...      national
# 19  Retail sales back to 93% of pre-COVID levels i...  ...      national
# 20  England record joint 2nd most international wi...  ...        sports
# 21  Man threatens to set himself on fire if India-...  ...        sports
# 22  Lloyd questions ICC for rating Ahmedabad pitch...  ...        sports
# 23  Dhana Lakshmi beats national record holder Dut...  ...        sports
# 24  Ex-UAE captain and UAE's highest ODI run-score...  ...        sports
# 25  Pics from Bumrah-Sanjana's pre-wedding ceremon...  ...        sports
# 26  19-yr-old Russian ice hockey player dies after...  ...        sports
# 27  Rohit returns to playing XI, India to try 3rd ...  ...        sports
# 28  I am totally at peace, find questions on ODI, ...  ...        sports
# 29  Virat Kohli makes error during toss, says 'Ind...  ...        sports
# 30  Wrestler Lance Von Erich claims he was in a tr...  ...        sports
# 31  KL Rahul records joint-most ducks by an Indian...  ...        sports
# 32  Sreeshankar qualifies for Olympics, sets new n...  ...        sports
# 33  39-yr-old Ibrahimovic comes out of retirement ...  ...        sports
# 34  Carolina Marin pulls out of All England Champi...  ...        sports
# 35  Ishan Kishan, Rishabh Pant will play in all 3 ...  ...        sports
# 36  No spectators allowed at ISSF Shooting World C...  ...        sports
# 37  Sarah Taylor 1st female cricketer to coach in ...  ...        sports
# 38  Yes, it may be true: Zidane on Ronaldo returni...  ...        sports
# 39  I'm back home, will continue to recover here: ...  ...        sports
# 40  OPPO F19 Pro series goes on sale today startin...  ...    technology
# 41  What is the cut Google has announced to fee it...  ...    technology
# 42  18-yr-old, who hacked Obama, Musk, Bill Gates'...  ...    technology
# 43  Uber grants 70,000 UK drivers workers' rights ...  ...    technology
# 44  American rapper Ja Rule auctions painting of F...  ...    technology
# 45  Apple supplier Foxconn considers Wisconsin, Me...  ...    technology
# 46  German man falls for fake Elon Musk scam, lose...  ...    technology
# 47  Prevented large-scale cyberattack by Russian h...  ...    technology
# 48  Nazara didn't invest aggressively in real mone...  ...    technology
# 49     Huawei to charge royalty for its 5G phone tech  ...    technology
# 50  Instagram will not let adults message teens wh...  ...    technology
# 51  5 US states join case against Google for weake...  ...    technology
# 52  Crypto platform suffers breach, contents worth...  ...    technology
# 53  Apple wins patent for modular wall unit system...  ...    technology
# 54  UC Browser removed from Chinese Android app st...  ...    technology
# 55  Digital art worth thousands of dollars stolen ...  ...    technology
# 56  GitHub employee fired for writing 'Nazi' refus...  ...    technology
# 57  Russia to block Twitter if banned content isn'...  ...    technology
# 58  US woman uses deepfake pics against daughter's...  ...    technology
# 59  Volkswagen couldn't build 1 lakh cars due to c...  ...    technology
#
# [60 rows x 3 columns]

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 177

# %%
#remove html tags
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text = soup.get_text()
  return new_text

html_tag('<html><h2> Some important info </h2></html>')
# Out:
# ' Some important info '

# %%
#expand Contraction
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand

con("Y'all can't expand I'd think")
# Out:
# Collecting contractions
#   Downloading https://files.pythonhosted.org/packages/0a/04/d5e0bb9f2cef5d15616ebf68087a725c5dbdd71bd422bcfb35d709f98ce7/contractions-0.0.48-py2.py3-none-any.whl
# Collecting textsearch>=0.0.21
#   Downloading https://files.pythonhosted.org/packages/d3/fe/021d7d76961b5ceb9f8d022c4138461d83beff36c3938dc424586085e559/textsearch-0.0.21-py2.py3-none-any.whl
# Collecting anyascii
#   Downloading https://files.pythonhosted.org/packages/09/c7/61370d9e3c349478e89a5554c1e5d9658e1e3116cc4f2528f568909ebdf1/anyascii-0.1.7-py3-none-any.whl (260kB)
#      |████████████████████████████████| 266kB 4.2MB/s
# Collecting pyahocorasick
#   Downloading https://files.pythonhosted.org/packages/4a/92/b3c70b8cf2b76f7e3e8b7243d6f06f7cb3bab6ada237b1bce57604c5c519/pyahocorasick-1.4.1.tar.gz (321kB)
#      |████████████████████████████████| 327kB 7.6MB/s
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.1-cp37-cp37m-linux_x86_64.whl size=85254 sha256=90e2f907a65cf1fce656b9cccd8c6081385d4a0f97f7e4276a7519fe93f63307
#   Stored in directory: /root/.cache/pip/wheels/e4/ab/f7/cb39270df8f6126f3dd4c33d302357167086db460968cfc80c
# Successfully built pyahocorasick
# Installing collected packages: anyascii, pyahocorasick, textsearch, contractions
# Successfully installed anyascii-0.1.7 contractions-0.0.48 pyahocorasick-1.4.1 textsearch-0.0.21
# 'you all can not expand I would think'

# %%
#special characters
import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s]'
  text = re.sub(pattern,'',text)
  return text

remove_sp("+-#skdm")
# Out:
# 'skdm'

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  tokens = [token.strip()for token in tokens]
  filtered_tokens = [token for token in tokens if token not in stopword_list]
  filtered_text = ' '.join(filtered_tokens)
  return filtered_text

# %%
remove_stopwords("The, and , if are all stopwards and even not")
# Out:
# 'The , , stopwards even not'

# %%
#Lower case
#html tags
#contractions
#special characters
#stop words

df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_article = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)

df.head()
# Out:
#                                        news_headline  ... news_category
# 0  bmc issues work home order teachers school sta...  ...      national
# 1  former union minister dilip gandhi tested posi...  ...      national
# 2  cong announces 14 names puducherry polls leave...  ...      national
# 3  himachal pradesh mp ram swaroop sharma found d...  ...      national
# 4  nia seizes mercedes used sachin vaze no plate ...  ...      national
#
# [5 rows x 3 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

df['compound'] = df['news_article'].apply(lambda x:vs.polarity_scores(x)['compound'])

# %%
df
# Out:
#                                         news_headline  ... compound
# 0   bmc issues work home order teachers school sta...  ...   0.4019
# 1   former union minister dilip gandhi tested posi...  ...   0.6597
# 2   cong announces 14 names puducherry polls leave...  ...   0.4019
# 3   himachal pradesh mp ram swaroop sharma found d...  ...  -0.9393
# 4   nia seizes mercedes used sachin vaze no plate ...  ...  -0.7096
# 5   india reports highest daily covid19 cases 2021...  ...  -0.2263
# 6   du teachers march cm residence protest delay g...  ...   0.0083
# 7   total lockdown pune not necessary right mayor ...  ...   0.4745
# 8   delhi govt sets education board gets registere...  ...   0.4767
# 9   no women shos delhi delhi commission women police  ...  -0.5563
# 10   bhojpuri actor 1 held delhi fake notes worth 50l  ...  -0.6486
# 11  hero indians pm sheikh mujibur rahmans birth a...  ...   0.9468
# 12  action schools reopening classes 15 ktaka mini...  ...  -0.1280
# 13  beneficiaries pune get covaxin due covishield ...  ...   0.2023
# 14       mother slain walayar girls contest kerala cm  ...  -0.8689
# 15   congress not nazi party rss rahul gandhi dissent  ...   0.0108
# 16  class 11 student others kidnap classmate praya...  ...  -0.8779
# 17  govt shut handicrafts export corp offer vrs staff  ...  -0.5574
# 18  health policy premium cannot arbitrarily hiked...  ...   0.7579
# 19  retail sales back 93 precovid levels february ...  ...   0.3400
# 20  england record joint 2nd international wins vs...  ...   0.1779
# 21  man threatens set fire indiaeng t20is continue...  ...   0.3049
# 22  lloyd questions icc rating ahmedabad pitch 3rd...  ...   0.2263
# 23  dhana lakshmi beats national record holder dut...  ...  -0.6597
# 24  exuae captain uaes highest odi runscorer banne...  ...  -0.7003
# 25  pics bumrahsanjanas prewedding ceremonies surf...  ...   0.7650
# 26  19yrold russian ice hockey player dies hit hea...  ...  -0.7423
# 27  rohit returns playing xi india try 3rd differe...  ...   0.4939
# 28  totally peace find questions odi t20i return l...  ...   0.9070
# 29  virat kohli makes error toss says india 21 eng...  ...  -0.1280
# 30  wrestler lance von erich claims train bombed b...  ...   0.3818
# 31  kl rahul records jointmost ducks indian t20i s...  ...   0.0000
# 32  sreeshankar qualifies olympics sets new nation...  ...   0.3400
# 33  39yrold ibrahimovic comes retirement fifa wc 2022  ...   0.0165
# 34    carolina marin pulls england championships 2021  ...  -0.6293
# 35  ishan kishan rishabh pant play 3 formats saba ...  ...   0.7783
# 36  no spectators allowed issf shooting world cup ...  ...  -0.2960
# 37  sarah taylor 1st female cricketer coach mens c...  ...   0.0000
# 38  yes may true zidane ronaldo returning real madrid  ...   0.8625
# 39           I back home continue recover tiger woods  ...  -0.6908
# 40  oppo f19 pro series goes sale today starting 2...  ...   0.5267
# 41   cut google announced fee collects app developers  ...   0.0772
# 42  18yrold hacked obama musk bill gates twitter a...  ...  -0.8910
# 43  uber grants 70000 uk drivers workers rights co...  ...   0.6908
# 44  american rapper ja rule auctions painting fyre...  ...   0.2023
# 45  apple supplier foxconn considers wisconsin mex...  ...   0.4215
# 46  german man falls fake elon musk scam loses bit...  ...  -0.7506
# 47  prevented largescale cyberattack russian hacke...  ...   0.3022
# 48  nazara not invest aggressively real money gami...  ...   0.2874
# 49                huawei charge royalty 5g phone tech  ...   0.0000
# 50  instagram not let adults message teens not follow  ...  -0.0428
# 51  5 us states join case google weakening ad comp...  ...  -0.7906
# 52  crypto platform suffers breach contents worth ...  ...  -0.8885
# 53  apple wins patent modular wall unit system sma...  ...   0.7184
# 54      uc browser removed chinese android app stores  ...  -0.3818
# 55  digital art worth thousands dollars stolen nft...  ...  -0.3612
# 56  github employee fired writing nazi refused tak...  ...  -0.9153
# 57  russia block twitter banned content not remove...  ...  -0.8625
# 58  us woman uses deepfake pics daughters cheerlea...  ...  -0.7269
# 59  volkswagen could not build 1 lakh cars due chi...  ...   0.3612
#
# [60 rows x 4 columns]

# %%
df.to_csv('inshort_news.csv',index=False)
x = df.iloc[:, -1]
y = df.iloc[:, 1]

# %%
# !pip install streamlit
# !pip install pyngrok==4.1.1
from pyngrok import ngrok
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.7/dist-packages (0.78.0)
# Requirement already satisfied: validators in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.18.2)
# Requirement already satisfied: base58 in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.1.0)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (4.2.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.1.14)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.1.5)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.12.4)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (4.1.0)
# Requirement already satisfied: pyarrow; python_version < "3.9" in /usr/local/lib/python3.7/dist-packages (from streamlit) (3.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.8.1)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (5.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from streamlit) (20.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.19.5)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.6.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (7.1.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.5.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from streamlit) (2.23.0)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit) (0.8.1)
# Requirement already satisfied: blinker in /usr/local/lib/python3.7/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit) (7.0.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from validators->streamlit) (1.15.0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from validators->streamlit) (4.4.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython->streamlit) (4.0.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.0->streamlit) (2018.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf!=3.11,>=3.6.0->streamlit) (54.0.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (2.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (5.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit) (1.24.3)
# Requirement already satisfied: smmap<4,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython->streamlit) (3.0.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.3.5)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (22.0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (2.6.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.3.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pyngrok==4.1.1 in /usr/local/lib/python3.7/dist-packages (4.1.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok==4.1.1) (3.13)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyngrok==4.1.1) (0.16.0)

# %%
# %%writefile app.py
import streamlit as st
st.title('Sentimental Analysis')
import pandas as pd
df = pd.read_csv('/content/inshort_news.csv')
x = df.iloc[:, -1]
y = df.iloc[:, 1]

num = st.number_input("Enter the integer between 0 to 59")

if(st.button('Submit')):
  if x[num]>= 0.05:
    st.write(y[num])
    st.write("The above statment is positive 😀")
  
  elif (x[num]> -0.05 and df.compound[num]< 0.05):
    st.write(y[num])
    st.write("The above statment is netural 🙂")
  
  elif x[num]<= -0.05:
    st.write(y[num])
    st.write("The above statment is negative ☹️")
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py &
url = ngrok.connect(port='8501')
url
# Out:
# nohup: appending output to 'nohup.out'
# 'http://559eabb7a11a.ngrok.io'
